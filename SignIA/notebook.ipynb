# %%
from fastai.vision.all import *

# %%
try : from ..MyModules.GestionImages import *
except : 
    sys.path.append("../MyModules/")
    from GestionImages import *

# %%
signs = search_images("code de la route",10)
display_url_img(signs[0])
# Out:
# <PIL.Image.Image image mode=RGB size=256x154>
